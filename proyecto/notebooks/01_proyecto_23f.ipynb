# %% [markdown]
# Proyecto ML — Evolución temporal de los temas en los documentos desclasificados del 23-F
# Está organizado en fases:- **Fase 1**: Configuración del entorno y carga inicial.- **Fase 2**: Análisis Exploratorio de los Datos (EDA).- **Fase 3**: Preprocesado del texto.- **Fase 4**: Modelado con BERTopic y LDA.- **Fase 5**: Análisis de estabilidad.- **Fase 6**: Análisis temporal e interpretación histórica.Cada fase está claramente marcada con un título de nivel 1 (`#`).

# %% [markdown]
# # Fase 1 — Configuración del entornoEn esta fase:
# 1. Montamos Google Drive (si estamos en Colab).
# 2. Configuramos las rutas relativas del proyecto.
# 3. Instalamos las dependencias necesarias.
# 4. Importamos los módulos del proyecto.

# %% [markdown]
# ## 1.1. Detectar entorno (Colab vs local) y montar Drive si procede

# %%
import google.colab
print("Ejecutando en Google Colab.")
# Out:
# Ejecutando en Google Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
print("Google Drive montado en /content/drive")
# Out:
# Mounted at /content/drive
# Google Drive montado en /content/drive

# %% [markdown]
# ## 1.2. Definir la ruta raíz del proyecto

# %%
from pathlib import Path
RUTA_PROYECTO = Path('/content/drive/MyDrive/proyecto_23f')

# Comprobamos que la ruta existe
assert RUTA_PROYECTO.exists(), f"No se encuentra la ruta: {RUTA_PROYECTO}"

# Definimos rutas relativas a la raíz del proyecto
RUTA_DATA_RAW   = RUTA_PROYECTO / 'data' / 'raw'
RUTA_DATA_PROC  = RUTA_PROYECTO / 'data' / 'processed'
RUTA_SRC        = RUTA_PROYECTO / 'src'
RUTA_OUT_FIG    = RUTA_PROYECTO / 'outputs' / 'figuras'
RUTA_OUT_MOD    = RUTA_PROYECTO / 'outputs' / 'modelos'

print(f"Raíz del proyecto:   {RUTA_PROYECTO}")
print(f"Datos raw:           {RUTA_DATA_RAW}")
print(f"Documentos en raw:   {len(list(RUTA_DATA_RAW.glob('*.json')))}")
# Out:
# Raíz del proyecto:   /content/drive/MyDrive/proyecto_23f
# Datos raw:           /content/drive/MyDrive/proyecto_23f/data/raw
# Documentos en raw:   158

# %% [markdown]
# ## 1.3. Instalación de dependencias (solo primera vez en Colab)

# %%
# !pip install -q -r {RUTA_PROYECTO}/requirements.txt
# !python -m spacy download es_core_news_sm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 88.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ## 1.4. Importar los módulos del proyecto

# %%
import sys
# Añadimos la carpeta src/ al path para poder importar nuestros módulos
if str(RUTA_PROYECTO) not in sys.path: sys.path.insert(0, str(RUTA_PROYECTO))
# Imports del proyecto (por ahora solo los esqueletos)
from src import carga_datos, preprocesado, modelado, visualizacion
# Imports de librerías principales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Configuración estética para los gráficos
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (10, 5)
print("Configuración inicial completada. Listo para empezar la Fase 2.")
# Out:
# Configuración inicial completada. Listo para empezar la Fase 2.

# %% [markdown]
# # Fase 2 — Análisis Exploratorio de los Datos*(Pendiente de desarrollar — se añadirá en el siguiente paso del proyecto)*

# %% [markdown]
# # Fase 3 — Preprocesado del texto*(Pendiente)*

# %% [markdown]
# # Fase 4 — Modelado: BERTopic y LDA*(Pendiente)*

# %% [markdown]
# # Fase 5 — Análisis de estabilidad*(Pendiente)*

# %% [markdown]
# # Fase 6 — Análisis temporal e interpretación histórica*(Pendiente)*
